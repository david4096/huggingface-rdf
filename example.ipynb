# %%
# !git clone https://github.com/david4096/huggingface-rdf.git
# Out:
# Cloning into 'huggingface-rdf'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 29 (delta 9), reused 19 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (29/29), 12.82 KiB | 3.21 MiB/s, done.

# %%
# !cd huggingface-rdf && python3 -m pip install .
# Out:
# Processing /data/huggingface-rdf
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 447 kB 20.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 562 kB 53.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 96 kB 11.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 179 kB 121.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 43 kB 4.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 106 kB 128.9 MB/s eta 0:00:01
# ...

# %%
import os
os.environ['HF_API_KEY'] = 'YOUR_TOKEN'
# !huggingface-rdf --fname huggingface.ttl --limit 10
# Out:
# INFO:huggingface_rdf:Starting the process to generate a Turtle file.
# INFO:huggingface_rdf:Turtle file generated successfully: [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'Memory']].

# %%
# !ls
# Out:
# Untitled.ipynb	huggingface-rdf  huggingface.ttl

# %%
import rdflib
g = rdflib.Graph()
g.parse('huggingface.ttl')
test_query = """
SELECT DISTINCT ?a ?b ?c WHERE {?a ?b ?c}"""

qres = g.query(test_query)
for row in qres:
    print(f"{row.b}")
# Out:
# https://schema.org/description
# https://schema.org/license
# http://mlcommons.org/croissant/dataType
# http://mlcommons.org/croissant/recordSet
# http://mlcommons.org/croissant/field
# https://schema.org/keywords
# http://mlcommons.org/croissant/fileSet
# http://mlcommons.org/croissant/fileSet
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# https://schema.org/description
# https://schema.org/name
# https://schema.org/description
# https://schema.org/keywords
# https://schema.org/creator
# http://mlcommons.org/croissant/fileSet
# https://schema.org/distribution
# https://schema.org/description
# https://schema.org/creator
# http://mlcommons.org/croissant/extract
# http://mlcommons.org/croissant/field
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# https://schema.org/description
# https://schema.org/keywords
# https://schema.org/name
# http://mlcommons.org/croissant/source
# https://schema.org/keywords
# http://mlcommons.org/croissant/fileSet
# https://schema.org/description
# ...
